# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x):
    return x**3

# %%
xrange = np.linspace(-10,10,100)
yrange = [f(x) for x in xrange]

# %%
plt.plot(xrange,yrange)
plt.show()

# %%
# !jupyter nbconvert Lesson00.ipynb --to html
# Out:
# [NbConvertApp] Converting notebook Lesson00.ipynb to html
# [NbConvertApp] Writing 584267 bytes to Lesson00.html
